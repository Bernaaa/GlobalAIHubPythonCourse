# %%
i = 1
while i <=2:
  print ('Türk tiyatrosunda sahneye çıkan ilk müslüman kadın oyuncu kimdir?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Afife Jale'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Afife Jale'):
    print('Yanlış cevap.')
    break
i = i+1
while i == 2:
  print ('2017 oscar ödül töreninde en iyi film oscarı hangi yapıma gitmiştir?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Moonlight'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Moonlight'):
    print('Yanlış cevap.')
    break
  i = i+1
while i == 2:
  print ('Güneş Sistemindeki hangi gezegenlerin halkası vardır?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Satürn, Jüpiter, Uranüs, Neptün'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Satürn, Jüpiter, Uranüs, Neptün'):
    print('Yanlış cevap.')
    break
i = i+1
while i == 3:
  print ('Mg hangi elementin simgesidir?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Magnezyum'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Magnezyum'):
    print('Yanlış cevap.')
    break
i = i+1
while i == 4:
  print ('Kaldırılan TEOG sisteminin açılımı neydi?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Temel Eğitimden Ortaöğretime Geçiş'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Temel Eğitimden Ortaöğretime Geçiş'):
    print('Yanlış cevap.')
    break
i = i+1
while i ==5:
  print ('Sergen Yalçın hangi futbol takımında forma giymiştir?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Etimesgut Şekerspor'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Etimesgut Şekerspor'):
    print('Yanlış cevap.')
    break
i = i+1
while i ==6:
  print ('Niyetçiler genellikle hangi hayvanı kullanarak niyet çektirirler?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Tavşan'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Tavşan'):
    print('Yanlış cevap.')
    break
i = i+1
while i ==7:
  print ('Mustafa Kemalin Ben taaruzu emretmiyorum ölmeyi emrediyorum diyerek askeri liderliğini gösterdiği cephe hangisidir?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Çanakkale Cephesi'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Çanakkale Cephesi'):
    print('Yanlış cevap.')
    break
i = i+1
while i == 8:
  print ('Yüzölçümü en küçük ilimiz hangisidir?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Yalova'):
    break
    print('Dogru cevap, 10 puan kazandınız.')
  if(cevap != 'Yalova'):
    print('Yanlış cevap.')
    break
i = i+1
while i == 9:
  print ('Hababam Sınıfı kim tarafından yazılmıştır?')
  cevap = input('Cevabı yazınız:')
  if(cevap == 'Rıfat Ilgaz'):
    print('Dogru cevap, 10 puan kazandınız.')
    break
  if(cevap != 'Rıfat Ilgaz'):
    print('Yanlış cevap.')
    break
